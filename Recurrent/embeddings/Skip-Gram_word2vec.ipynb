# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import random
from collections import Counter

def get_prob(word):
    return (1 - np.sqrt(1e-5/freqs[word]))

word_counts = Counter(int_words)
total_counts = len(int_words)
freqs = {word: count/total_counts for word, count in word_counts.items()}
prob_drop = {word : get_prob(word) for word in word_counts}

# %%
## Your code here
train_words = [word for word in int_words if random.random() < (1 - prob_drop[word])] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    neighborhood = []
    rand_no = np.random.randint(1, window_size+1)
    start = idx - rand_no if (idx - rand_no) > 0 else 0
    end = idx + rand_no
    target_words = set(words[start:idx] + words[idx+1:end+1]) # as we already have the word with idx we used idx + 1
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(shape=[None], dtype=tf.int32, name='inputs')
    labels = tf.placeholder(shape=[None, None], dtype=tf.int32, name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6538 0.0239 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6236 0.0219 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4973 0.0223 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6363 0.0234 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5462 0.0224 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5210 0.0234 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5623 0.0237 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5527 0.0209 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4845 0.0232 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4278 0.0216 sec/batch
# Nearest to all: chervil, sidgwick, phloem, reindeer, macaroni, sonorities, chosenness, deprogrammings,
# Nearest to five: holdout, estis, niacin, apostolicity, tirana, navigable, randori, electric,
# Nearest to time: isps, distillation, dharmas, harmoniously, fairytale, darpa, yorke, style,
# Nearest to between: pollen, predate, mitzvot, marimba, throop, preahm, boating, sapa,
# Nearest to many: indirect, normed, oslo, misinformation, marcus, gillis, servius, zombie,
# Nearest to new: cantos, conversant, dhtml, prestwich, forbidding, motorists, muso, plesiosaur,
# Nearest to after: profiled, cabbie, bikers, brendan, pedophile, incarnated, aether, ryaku,
# Nearest to system: clans, purposes, farthest, chaser, brutally, novices, skolem, erects,
# Nearest to running: dualistic, worldcon, ime, bunk, hooked, masud, surmise, jastrow,
# Nearest to event: steer, ketones, keaton, memorial, lavey, messianic, temmu, boca,
# Nearest to bible: troughton, bawdy, sourcebook, sprawling, shadowy, feinstein, gelder, globalsecurity,
# Nearest to additional: yaobang, drm, rung, screech, individuals, wielkopolska, sahelian, proteg,
# Nearest to professional: ceremonial, cable, chateau, bloodletting, mannerist, goldfinger, large, uther,
# Nearest to mean: korman, tommie, paderborn, cofinal, possess, gaseous, pyrenees, watercolors,
# Nearest to pressure: wankel, scottish, oracle, morale, screwball, quintessentially, gz, valyria,
# Nearest to discovered: pool, mycobacterium, lancers, padma, due, everest, atlanteans, preventing,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4917 0.0188 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3730 0.0195 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3479 0.0229 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2162 0.0224 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1988 0.0211 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1667 0.0198 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1163 0.0227 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0617 0.0218 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0060 0.0216 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9767 0.0237 sec/batch
# Nearest to all: schema, describes, like, isotopes, population, banker, sidgwick, assembles,
# Nearest to five: navigable, electric, holdout, apostolicity, buyer, niacin, estis, unclaimed,
# Nearest to time: isps, style, distillation, lamps, dharmas, next, captain, darpa,
# Nearest to between: predate, mitzvot, pollen, need, preahm, reach, bought, then,
# Nearest to many: indirect, modern, oslo, normed, movement, marcus, misinformation, worldwide,
# Nearest to new: cantos, dhtml, conversant, forbidding, prestwich, motorists, going, decoded,
# Nearest to after: bikers, following, near, profiled, possibilities, brendan, cabbie, musical,
# Nearest to system: purposes, farthest, loose, speculated, brutally, theme, chaser, stress,
# Nearest to running: dualistic, ime, worldcon, deeply, film, take, hooked, hostile,
# Nearest to event: steer, defeat, memorial, ketones, trustworthy, messianic, taboo, powerhouse,
# Nearest to bible: bawdy, troughton, sourcebook, gelder, sprawling, ride, feinstein, de,
# Nearest to additional: yaobang, individuals, varying, drm, flavorings, bellori, architecture, rung,
# Nearest to professional: ceremonial, large, cable, being, reasonable, around, chateau, restoration,
# Nearest to mean: korman, cofinal, paderborn, exactly, possess, decency, regulate, constant,
# Nearest to pressure: scottish, wankel, oracle, morale, means, standardization, questioned, fixed,
# Nearest to discovered: pool, due, earlier, lancers, everest, preventing, mycobacterium, socially,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9223 0.0230 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8720 0.0226 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8831 0.0221 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8800 0.0236 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7921 0.0223 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8303 0.0223 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7887 0.0214 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7785 0.0224 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7891 0.0228 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7881 0.0224 sec/batch
# Nearest to all: elementary, agenda, isotopes, reindeer, assembles, sonorities, expression, schema,
# Nearest to five: navigable, van, apostolicity, buyer, swear, electric, holdout, estis,
# Nearest to time: isps, distillation, style, lamps, dharmas, stringed, employment, captain,
# Nearest to between: pollen, predate, mitzvot, need, sapa, erased, preahm, boating,
# Nearest to many: indirect, oslo, misinformation, normed, modern, exclusion, marcus, movement,
# Nearest to new: dhtml, cantos, conversant, forbidding, motorists, prestwich, riley, spellings,
# Nearest to after: campaigned, brendan, cabbie, players, musical, possibilities, bikers, near,
# Nearest to system: purposes, clans, loose, farthest, speculated, brutally, stress, theme,
# Nearest to running: worldcon, hooked, dualistic, ime, deeply, colony, hostile, film,
# Nearest to event: steer, memorial, messianic, trustworthy, defeat, ketones, taboo, frank,
# Nearest to bible: sourcebook, bawdy, troughton, judaism, sprawling, ride, explorers, gelder,
# Nearest to additional: yaobang, individuals, drm, flavorings, backward, champions, varying, storing,
# Nearest to professional: ceremonial, large, cable, chateau, handy, being, bloodletting, restoration,
# Nearest to mean: possess, exactly, paderborn, regulate, korman, cofinal, aftermath, constant,
# Nearest to pressure: scottish, wankel, oracle, minerals, standardization, morale, screwball, headquarters,
# Nearest to discovered: pool, lancers, mycobacterium, preventing, earlier, due, everest, hide,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8027 0.0207 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7617 0.0237 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7367 0.0213 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7249 0.0210 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7327 0.0203 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7022 0.0229 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7000 0.0234 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7299 0.0224 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6658 0.0227 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6834 0.0183 sec/batch
# Nearest to all: isotopes, macaroni, reindeer, agenda, elementary, sonorities, assembles, blu,
# Nearest to five: zero, two, navigable, soldier, one, apostolicity, van, american,
# Nearest to time: isps, distillation, cultivates, lamps, stringed, yorke, employment, harmoniously,
# Nearest to between: pollen, sapa, erased, predate, preahm, mitzvot, need, blown,
# Nearest to many: oslo, indirect, misinformation, modern, normed, exclusion, movement, shake,
# Nearest to new: dhtml, forbidding, conversant, riley, cantos, motorists, prestwich, edison,
# Nearest to after: campaigned, profiled, musical, brendan, near, cabbie, ryaku, plato,
# Nearest to system: purposes, farthest, clans, loose, usable, speculated, stress, koine,
# Nearest to running: hooked, bunk, worldcon, ime, dualistic, colony, pamphlet, clashes,
# Nearest to event: steer, ketones, memorial, taboo, trustworthy, keaton, messianic, lavey,
# Nearest to bible: sourcebook, judaism, bawdy, troughton, sprawling, hierarchy, ncb, globalsecurity,
# Nearest to additional: yaobang, individuals, drm, flavorings, backward, rung, bellori, storing,
# Nearest to professional: goldfinger, handy, ceremonial, chateau, large, bloodletting, cable, scrolls,
# Nearest to mean: possess, exactly, paderborn, korman, regulate, this, constant, cofinal,
# Nearest to pressure: wankel, scottish, oracle, minerals, morale, jain, screwball, fixed,
# Nearest to discovered: pool, everest, lancers, mycobacterium, hide, padma, preventing, rotations,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6481 0.0212 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6459 0.0212 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6089 0.0181 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6187 0.0233 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6417 0.0212 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6493 0.0208 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6116 0.0163 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5394 0.0233 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5045 0.0223 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4958 0.0229 sec/batch
# Nearest to all: macaroni, elementary, isotopes, sonorities, like, deprogrammings, blu, agenda,
# Nearest to five: zero, two, navigable, van, one, soldier, american, three,
# Nearest to time: distillation, isps, harmoniously, cultivates, stringed, style, yorke, lamps,
# Nearest to between: pollen, sapa, erased, need, predate, preahm, mitzvot, boating,
# Nearest to many: oslo, indirect, misinformation, modern, normed, movement, exclusion, redistribution,
# Nearest to new: dhtml, conversant, forbidding, cantos, riley, edison, motorists, prestwich,
# Nearest to after: campaigned, profiled, ryaku, brendan, players, cabbie, parker, possibilities,
# Nearest to system: purposes, farthest, usable, cgt, clans, surveys, koine, loose,
# Nearest to running: hooked, ime, bunk, worldcon, dualistic, surmise, modem, ensured,
# Nearest to event: steer, ketones, memorial, keaton, taboo, eschatological, lavey, messianic,
# Nearest to bible: judaism, sourcebook, troughton, bawdy, sprawling, hierarchy, ncb, jewish,
# Nearest to additional: yaobang, drm, individuals, flavorings, olympiads, bellori, backward, screech,
# Nearest to professional: goldfinger, handy, chateau, bloodletting, scrolls, ceremonial, mahesh, pant,
# Nearest to mean: exactly, possess, constant, this, paderborn, regulate, arithmetic, korman,
# Nearest to pressure: wankel, minerals, fixed, turbines, oracle, jain, standardization, rowley,
# Nearest to discovered: pool, lancers, padma, everest, rotations, hide, textual, atlanteans,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4909 0.0235 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4937 0.0213 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4651 0.0227 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5279 0.0220 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4764 0.0201 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4870 0.0209 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4663 0.0231 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4176 0.0228 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4346 0.0230 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4426 0.0234 sec/batch
# Nearest to all: macaroni, isotopes, sonorities, elementary, deprogrammings, chervil, agenda, like,
# Nearest to five: zero, navigable, two, three, soldier, van, apostolicity, one,
# Nearest to time: distillation, isps, harmoniously, stringed, cultivates, style, fairytale, tamm,
# Nearest to between: pollen, erased, sapa, mitzvot, need, diverse, thirdly, relative,
# Nearest to many: indirect, oslo, misinformation, modern, normed, unconsciously, spiritual, genetically,
# Nearest to new: forbidding, dhtml, conversant, cantos, motorists, riley, ales, edison,
# Nearest to after: campaigned, brendan, players, ryaku, cabbie, profiled, possibilities, pedophile,
# Nearest to system: purposes, farthest, usable, cgt, access, verification, novices, bit,
# Nearest to running: hooked, ime, bunk, worldcon, kagan, surmise, modem, marginalize,
# Nearest to event: steer, ketones, trustworthy, memorial, lavey, lichfield, keaton, centimeter,
# Nearest to bible: judaism, prophets, jewish, bawdy, sourcebook, troughton, biblical, hierarchy,
# Nearest to additional: drm, yaobang, flavorings, olympiads, storing, bellori, individuals, screech,
# Nearest to professional: goldfinger, handy, ceremonial, scrolls, bloodletting, chateau, mahesh, concr,
# Nearest to mean: exactly, constant, possess, paderborn, this, regulate, arithmetic, cofinal,
# Nearest to pressure: minerals, wankel, fixed, turbines, occurs, jain, standardization, nutrient,
# Nearest to discovered: lancers, pool, atlanteans, textual, padma, everest, mycobacterium, rotations,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4392 0.0238 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4327 0.0218 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4256 0.0195 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4077 0.0233 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4313 0.0242 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4419 0.0230 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3559 0.0242 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3750 0.0221 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4294 0.0228 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3866 0.0220 sec/batch
# Nearest to all: elementary, macaroni, chosenness, like, deprogrammings, sonorities, chervil, strictest,
# Nearest to five: zero, two, navigable, three, one, apostolicity, van, expenditures,
# Nearest to time: distillation, harmoniously, isps, stringed, fairytale, cultivates, yorke, lamps,
# Nearest to between: pollen, erased, sapa, mitzvot, need, relative, satin, luthier,
# Nearest to many: oslo, indirect, misinformation, modern, unconsciously, normed, genetically, spiritual,
# Nearest to new: dhtml, riley, ales, conversant, cantos, forbidding, edison, hoskins,
# Nearest to after: campaigned, cabbie, brendan, players, ryaku, profiled, possibilities, aranese,
# Nearest to system: purposes, farthest, usable, cgt, access, bit, novices, lfhild,
# Nearest to running: hooked, bunk, ime, modem, kagan, worldcon, ensured, marginalize,
# Nearest to event: steer, ketones, lichfield, trustworthy, lavey, bdsm, centimeter, boca,
# Nearest to bible: judaism, jewish, prophets, biblical, christians, bawdy, sourcebook, hierarchy,
# Nearest to additional: drm, yaobang, flavorings, luoyang, storing, olympiads, bellori, korzybski,
# Nearest to professional: goldfinger, handy, scrolls, mahesh, zeitgeist, chateau, concr, classless,
# Nearest to mean: exactly, constant, possess, paderborn, calculate, this, regulate, cofinal,
# Nearest to pressure: minerals, turbines, fixed, wankel, nutrient, relativistic, jain, intermediate,
# Nearest to discovered: everest, padma, rotations, pool, atlanteans, lancers, textual, diddy,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3936 0.0188 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3939 0.0178 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3581 0.0165 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3480 0.0183 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3936 0.0177 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.4000 0.0189 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4032 0.0201 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3635 0.0187 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3534 0.0205 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3345 0.0218 sec/batch
# Nearest to all: macaroni, deprogrammings, elementary, chosenness, like, describes, ideogram, trademarked,
# Nearest to five: zero, two, three, navigable, one, seven, approximately, apostolicity,
# Nearest to time: harmoniously, distillation, isps, cultivates, stringed, fairytale, yorke, unsure,
# Nearest to between: erased, pollen, sapa, relative, diverse, need, mitzvot, thirdly,
# Nearest to many: oslo, indirect, misinformation, modern, while, unconsciously, genetically, normed,
# Nearest to new: dhtml, riley, ales, forbidding, cantos, edison, conversant, motorists,
# Nearest to after: campaigned, reconquest, brendan, aranese, cabbie, ryaku, legalization, garbo,
# Nearest to system: usable, purposes, access, farthest, cgt, occam, bit, novices,
# Nearest to running: bunk, hooked, ime, ensured, modem, kagan, losing, worldcon,
# Nearest to event: ketones, steer, trustworthy, boca, lichfield, bdsm, centimeter, lavey,
# Nearest to bible: judaism, biblical, prophets, jewish, christians, tradition, sourcebook, presbyter,
# Nearest to additional: drm, yaobang, flavorings, luoyang, korzybski, rung, olympiads, storing,
# Nearest to professional: goldfinger, handy, zeitgeist, mahesh, classless, ceremonial, chateau, scrolls,
# Nearest to mean: exactly, constant, calculate, paderborn, this, possess, tommie, cofinal,
# Nearest to pressure: minerals, turbines, wankel, nutrient, hotol, brane, jain, fixed,
# Nearest to discovered: rotations, padma, everest, textual, abundance, atlanteans, evaporate, pool,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3554 0.0199 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2920 0.0206 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3988 0.0226 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3866 0.0219 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3838 0.0233 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2549 0.0223 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2871 0.0220 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3420 0.0233 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2071 0.0225 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2968 0.0236 sec/batch
# Nearest to all: macaroni, elementary, like, chosenness, deprogrammings, inflorescence, describes, ideogram,
# Nearest to five: zero, two, three, one, seven, navigable, six, soldier,
# Nearest to time: harmoniously, distillation, isps, cultivates, stringed, unsure, yorke, fairytale,
# Nearest to between: erased, sapa, pollen, relative, luthier, diverse, mitzvot, satin,
# Nearest to many: oslo, indirect, modern, misinformation, unconsciously, genetically, badly, while,
# Nearest to new: dhtml, riley, forbidding, edison, ales, motorists, hoskins, cantos,
# Nearest to after: campaigned, reconquest, brendan, garbo, legalization, aranese, cabbie, ryaku,
# Nearest to system: usable, purposes, cgt, farthest, access, bit, occam, coolness,
# Nearest to running: hooked, ime, bunk, modem, kagan, ensured, powerpc, nl,
# Nearest to event: steer, lichfield, trustworthy, boca, ketones, centimeter, gonorrhea, lavey,
# Nearest to bible: judaism, jewish, biblical, prophets, sourcebook, christians, tradition, bawdy,
# Nearest to additional: drm, yaobang, luoyang, olympiads, flavorings, korzybski, bellori, crossbow,
# Nearest to professional: goldfinger, handy, mahesh, classless, zeitgeist, rhinoceros, ceremonial, concr,
# Nearest to mean: exactly, constant, calculate, this, paderborn, arithmetic, specify, pi,
# Nearest to pressure: turbines, minerals, wankel, jain, valyria, hotol, rowley, morale,
# Nearest to discovered: everest, padma, devolving, evaporate, atlanteans, rotations, abundance, tiers,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3205 0.0233 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3033 0.0222 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3556 0.0092 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2253 0.0199 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2320 0.0219 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2178 0.0224 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2292 0.0223 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2344 0.0213 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2264 0.0226 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1968 0.0224 sec/batch
# Nearest to all: macaroni, like, deprogrammings, chosenness, palestine, elementary, chervil, inflorescence,
# Nearest to five: zero, two, three, one, seven, navigable, six, approximately,
# Nearest to time: harmoniously, unsure, isps, cultivates, distillation, stringed, fairytale, next,
# Nearest to between: erased, sapa, pollen, relative, luthier, satin, diverse, skirmishes,
# Nearest to many: oslo, modern, indirect, misinformation, unconsciously, while, genetically, fai,
# Nearest to new: dhtml, edison, riley, forbidding, ales, motorists, oversee, jedi,
# Nearest to after: reconquest, campaigned, aranese, he, brendan, legalization, sulpicius, ryaku,
# Nearest to system: usable, purposes, cgt, farthest, access, internationalization, coolness, occam,
# Nearest to running: hooked, ime, bunk, modem, powerpc, kagan, losing, surmise,
# Nearest to event: trustworthy, lichfield, steer, boca, centimeter, ketones, lavey, bdsm,
# Nearest to bible: judaism, biblical, prophets, jewish, testament, sourcebook, christians, hierarchy,
# Nearest to additional: drm, yaobang, luoyang, olympiads, storing, rung, flavorings, bellori,
# Nearest to professional: goldfinger, handy, mahesh, rhinoceros, classless, homeward, amateur, concr,
# Nearest to mean: exactly, calculate, paderborn, constant, tommie, arithmetic, cofinal, specify,
# Nearest to pressure: turbines, wankel, minerals, morale, hotol, valyria, jain, rowley,
# Nearest to discovered: padma, everest, evaporate, predicted, devolving, atlanteans, draconic, abundance,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2616 0.0224 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2206 0.0239 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2217 0.0195 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1101 0.0221 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1827 0.0224 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2010 0.0230 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1703 0.0235 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1769 0.0218 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1947 0.0210 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1767 0.0222 sec/batch
# Nearest to all: macaroni, like, deprogrammings, bocce, elementary, strictest, ideogram, chosenness,
# Nearest to five: zero, two, three, one, seven, four, navigable, six,
# Nearest to time: unsure, harmoniously, isps, stringed, fairytale, next, cultivates, unimpressed,
# Nearest to between: erased, relative, pollen, sapa, luthier, satin, skirmishes, mitzvot,
# Nearest to many: oslo, misinformation, modern, genetically, unconsciously, indirect, ephedrine, fai,
# Nearest to new: dhtml, riley, edison, forbidding, ales, jedi, oversee, motorists,
# Nearest to after: reconquest, campaigned, cabbie, brendan, players, he, defeating, shortages,
# Nearest to system: purposes, usable, cgt, occam, farthest, internationalization, operating, tcl,
# Nearest to running: bunk, hooked, kagan, modem, ime, powerpc, losing, nl,
# Nearest to event: centimeter, trustworthy, lichfield, ketones, steer, macrinus, bdsm, brezhnev,
# Nearest to bible: judaism, biblical, jewish, prophets, sourcebook, testament, hierarchy, presbyter,
# Nearest to additional: drm, olympiads, yaobang, luoyang, flavorings, bellori, storing, rung,
# Nearest to professional: goldfinger, rhinoceros, handy, classless, mahesh, gridiron, amateur, homeward,
# Nearest to mean: exactly, paderborn, cofinal, calculate, tommie, constant, millimetres, elevation,
# Nearest to pressure: turbines, wankel, minerals, morale, solute, hotol, brane, valyria,
# Nearest to discovered: abundance, evaporate, predicted, acid, found, padma, draconic, tiers,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1608 0.0218 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2038 0.0217 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1736 0.0221 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1599 0.0233 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1953 0.0232 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1813 0.0227 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2123 0.0222 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1400 0.0221 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1305 0.0223 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1629 0.0226 sec/batch
# Nearest to all: macaroni, like, deprogrammings, chosenness, inflorescence, palestine, ideogram, objectivist,
# Nearest to five: zero, two, three, one, seven, four, six, approximately,
# Nearest to time: unsure, harmoniously, isps, stringed, fairytale, lamps, next, legato,
# Nearest to between: erased, relative, luthier, pollen, sapa, skirmishes, baserunners, satin,
# Nearest to many: oslo, unconsciously, misinformation, genetically, fai, indirect, modern, ephedrine,
# Nearest to new: riley, dhtml, edison, oversee, forbidding, jedi, ambivalent, ales,
# Nearest to after: reconquest, campaigned, brendan, he, aranese, cabbie, defeating, legalization,
# Nearest to system: usable, purposes, cgt, internationalization, occam, tcl, inhalant, lfhild,
# Nearest to running: hooked, bunk, modem, ime, kagan, powerpc, losing, ensured,
# Nearest to event: centimeter, trustworthy, steer, ketones, gonorrhea, macrinus, brezhnev, lichfield,
# Nearest to bible: judaism, biblical, jewish, prophets, sourcebook, testament, hierarchy, bawdy,
# Nearest to additional: drm, yaobang, luoyang, olympiads, flavorings, rung, korzybski, bellori,
# Nearest to professional: goldfinger, handy, mahesh, rhinoceros, classless, amateur, gridiron, homeward,
# Nearest to mean: exactly, paderborn, cofinal, tommie, millimetres, cmmi, calculate, constant,
# Nearest to pressure: turbines, wankel, solute, hotol, proportional, minerals, resistance, valyria,
# Nearest to discovered: abundance, predicted, evaporate, acid, found, kepler, padma, everest,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1945 0.0227 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1535 0.0220 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2038 0.0204 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1771 0.0204 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.2011 0.0234 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1176 0.0222 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1588 0.0230 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1350 0.0223 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1910 0.0234 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1988 0.0217 sec/batch
# Nearest to all: macaroni, palestine, bocce, objectivist, petitioning, chosenness, like, deprogrammings,
# Nearest to five: zero, two, three, one, seven, four, six, eight,
# Nearest to time: unsure, harmoniously, isps, fairytale, next, employment, yorke, outskirts,
# Nearest to between: sapa, erased, skirmishes, luthier, relative, baserunners, artaxerxes, mede,
# Nearest to many: oslo, misinformation, fai, genetically, indirect, esdi, unconsciously, ryder,
# Nearest to new: riley, dhtml, edison, jedi, tacoma, ambivalent, pitman, oversee,
# Nearest to after: reconquest, campaigned, he, brendan, aranese, defeating, jailed, cabbie,
# Nearest to system: usable, purposes, cgt, lfhild, inhalant, skolem, internationalization, occam,
# Nearest to running: hooked, bunk, kagan, modem, ime, powerpc, losing, carts,
# Nearest to event: centimeter, trustworthy, macrinus, steer, brezhnev, lichfield, substring, branes,
# Nearest to bible: judaism, biblical, prophets, jewish, hierarchy, sourcebook, testament, bawdy,
# Nearest to additional: drm, yaobang, luoyang, olympiads, rung, korzybski, bellori, flavorings,
# Nearest to professional: goldfinger, mahesh, handy, classless, amateur, rhinoceros, mcpherson, gridiron,
# Nearest to mean: exactly, paderborn, cofinal, calculate, cmmi, specify, constant, tommie,
# Nearest to pressure: turbines, wankel, minerals, solute, proportional, hotol, valyria, morale,
# Nearest to discovered: predicted, abundance, padma, devolving, found, evaporate, everest, kepler,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2247 0.0220 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1191 0.0222 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1276 0.0227 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1415 0.0236 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0183 0.0232 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1521 0.0222 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1455 0.0232 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1449 0.0234 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1673 0.0043 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1056 0.0235 sec/batch
# Nearest to all: macaroni, deprogrammings, like, chosenness, dressage, palestine, inflorescence, bocce,
# Nearest to five: zero, two, three, one, seven, six, four, approximately,
# Nearest to time: unsure, harmoniously, isps, driving, fairytale, next, unimpressed, subtracted,
# Nearest to between: sapa, luthier, erased, relative, skirmishes, baserunners, satin, mede,
# Nearest to many: oslo, unconsciously, genetically, modern, fai, ephedrine, while, misinformation,
# Nearest to new: riley, dhtml, edison, jedi, pitman, forbidding, tacoma, characterisation,
# Nearest to after: reconquest, campaigned, he, through, cabbie, aranese, brendan, shortages,
# Nearest to system: usable, purposes, operating, cgt, tcl, inhalant, occam, lfhild,
# Nearest to running: bunk, powerpc, hooked, kagan, modem, carts, ime, nl,
# Nearest to event: centimeter, brezhnev, trustworthy, steer, macrinus, lichfield, branes, substring,
# Nearest to bible: judaism, biblical, jewish, prophets, sourcebook, testament, hierarchy, bawdy,
# Nearest to additional: drm, olympiads, luoyang, yaobang, bellori, rung, flavorings, originally,
# Nearest to professional: goldfinger, mahesh, amateur, gridiron, handy, classless, rhinoceros, education,
# Nearest to mean: exactly, paderborn, cofinal, calculate, specify, cmmi, constant, millimetres,
# Nearest to pressure: wankel, turbines, valyria, solute, proportional, minerals, hotol, resistance,
# Nearest to discovered: predicted, found, abundance, kepler, padma, discovers, heliocentric, devolving,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0580 0.0226 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0736 0.0229 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0829 0.0181 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0343 0.0185 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0849 0.0229 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0389 0.0212 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1166 0.0226 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0701 0.0216 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1045 0.0218 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0263 0.0219 sec/batch
# Nearest to all: macaroni, dressage, inflorescence, palestine, bocce, chosenness, like, clutch,
# Nearest to five: two, zero, three, one, seven, six, four, eight,
# Nearest to time: unsure, harmoniously, subtracted, isps, unimpressed, next, mastiff, legato,
# Nearest to between: sapa, erased, luthier, mede, relative, baserunners, pollen, skirmishes,
# Nearest to many: oslo, unconsciously, while, modern, indirect, wellcome, genetically, esdi,
# Nearest to new: dhtml, riley, jedi, edison, forbidding, pitman, characterisation, oversee,
# Nearest to after: reconquest, he, campaigned, cabbie, brendan, shortages, aranese, chargers,
# Nearest to system: usable, purposes, operating, tcl, cgt, inhalant, internationalization, lfhild,
# Nearest to running: hooked, bunk, powerpc, kagan, carts, modem, intend, losing,
# Nearest to event: centimeter, trustworthy, brezhnev, steer, macrinus, lichfield, memorial, clevelanders,
# Nearest to bible: judaism, jewish, biblical, prophets, testament, translations, sourcebook, translation,
# Nearest to additional: drm, olympiads, yaobang, luoyang, flavorings, rung, bellori, korzybski,
# Nearest to professional: goldfinger, amateur, gridiron, mahesh, education, rhinoceros, handy, varsity,
# Nearest to mean: exactly, paderborn, cofinal, elevation, specify, cmmi, calculate, constant,
# Nearest to pressure: turbines, wankel, solute, minerals, resistance, hotol, valyria, proportional,
# Nearest to discovered: found, predicted, padma, observatory, evaporate, devolving, abundance, kepler,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0229 0.0216 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0483 0.0220 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0234 0.0219 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0850 0.0226 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0708 0.0238 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0489 0.0232 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0791 0.0217 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1086 0.0239 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0265 0.0231 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0766 0.0235 sec/batch
# Nearest to all: macaroni, chosenness, carelessly, inflorescence, dressage, like, reindeer, breaking,
# Nearest to five: two, zero, three, one, seven, six, four, eight,
# Nearest to time: unsure, harmoniously, subtracted, unimpressed, legato, isps, monopoles, stood,
# Nearest to between: luthier, sapa, erased, pollen, relative, mede, baserunners, caliente,
# Nearest to many: unconsciously, oslo, genetically, modern, wellcome, esdi, while, misinformation,
# Nearest to new: riley, dhtml, edison, characterisation, ambivalent, jedi, pitman, elitism,
# Nearest to after: he, reconquest, cabbie, aranese, brendan, shuttle, chargers, trollh,
# Nearest to system: usable, purposes, operating, lfhild, cgt, inhalant, internationalization, tcl,
# Nearest to running: powerpc, bunk, kagan, modem, hooked, carts, deeply, ime,
# Nearest to event: centimeter, brezhnev, trustworthy, phasing, memorial, macrinus, other, pontificate,
# Nearest to bible: jewish, judaism, biblical, prophets, testament, sourcebook, translations, masoretic,
# Nearest to additional: drm, olympiads, luoyang, yaobang, direcci, flavorings, korzybski, originally,
# Nearest to professional: goldfinger, gridiron, amateur, mahesh, education, handy, rhinoceros, holst,
# Nearest to mean: exactly, cofinal, elevation, paderborn, calculate, cmmi, specify, millimetres,
# Nearest to pressure: wankel, turbines, solute, proportional, minerals, valyria, resistance, mech,
# Nearest to discovered: found, predicted, abundance, observatory, padma, astrologer, kepler, evaporate,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0920 0.0240 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0856 0.0225 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0971 0.0229 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0308 0.0231 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0520 0.0227 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0506 0.0192 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0577 0.0227 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0825 0.0212 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0698 0.0221 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0773 0.0224 sec/batch
# Nearest to all: chosenness, macaroni, palestine, objectivist, carelessly, inflorescence, dressage, reindeer,
# Nearest to five: zero, two, three, one, seven, six, four, eight,
# Nearest to time: unsure, harmoniously, subtracted, unimpressed, stood, isps, driving, fairytale,
# Nearest to between: luthier, mede, sapa, baserunners, erased, relative, skirmishes, artaxerxes,
# Nearest to many: oslo, unconsciously, genetically, wellcome, while, badly, misinformation, ephedrine,
# Nearest to new: riley, dhtml, edison, jedi, characterisation, forbidding, pitman, ambivalent,
# Nearest to after: reconquest, he, aranese, was, through, cabbie, conquest, shuttle,
# Nearest to system: usable, purposes, brokered, lfhild, cgt, operating, internationalization, inhalant,
# Nearest to running: hooked, bunk, kagan, powerpc, carts, deeply, modem, tuck,
# Nearest to event: centimeter, brezhnev, trustworthy, phasing, memorial, macrinus, clevelanders, saturdays,
# Nearest to bible: judaism, biblical, jewish, prophets, testament, sourcebook, masoretic, septuagint,
# Nearest to additional: drm, yaobang, olympiads, direcci, luoyang, flavorings, korzybski, rung,
# Nearest to professional: goldfinger, amateur, gridiron, handy, education, rhinoceros, battering, holst,
# Nearest to mean: exactly, paderborn, elevation, cofinal, cmmi, calculate, specify, harmonies,
# Nearest to pressure: wankel, turbines, solute, proportional, mech, minerals, valyria, hotol,
# Nearest to discovered: found, padma, heliocentric, predicted, astrologer, devolving, observatory, kepler,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0457 0.0239 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0286 0.0225 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0609 0.0231 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0461 0.0237 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0927 0.0233 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1112 0.0224 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1324 0.0228 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0397 0.0226 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0664 0.0218 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0623 0.0221 sec/batch
# Nearest to all: chosenness, macaroni, inflorescence, dressage, bocce, objectivist, palestine, carelessly,
# Nearest to five: two, zero, three, one, seven, six, four, nine,
# Nearest to time: unsure, subtracted, harmoniously, driving, mastiff, unimpressed, isps, fairytale,
# Nearest to between: relative, luthier, mede, baserunners, erased, sapa, skirmishes, artaxerxes,
# Nearest to many: oslo, unconsciously, genetically, modern, badly, wellcome, mpaja, teleplay,
# Nearest to new: riley, dhtml, edison, characterisation, elitism, tacoma, island, jedi,
# Nearest to after: reconquest, he, pathogen, cabbie, aranese, brendan, shuttle, trollh,
# Nearest to system: usable, purposes, operating, brokered, lfhild, inhalant, cgt, internationalization,
# Nearest to running: kagan, hooked, powerpc, bunk, carts, modem, tuck, deeply,
# Nearest to event: trustworthy, brezhnev, centimeter, phasing, macrinus, clevelanders, saturdays, memorial,
# Nearest to bible: biblical, judaism, jewish, prophets, testament, sourcebook, hierarchy, masoretic,
# Nearest to additional: drm, olympiads, yaobang, luoyang, direcci, originally, flavorings, rung,
# Nearest to professional: goldfinger, amateur, gridiron, mahesh, education, handy, soccer, rhinoceros,
# Nearest to mean: exactly, elevation, paderborn, cofinal, cmmi, calculate, specify, parseval,
# Nearest to pressure: wankel, turbines, solute, proportional, mech, valyria, resistance, hotol,
# Nearest to discovered: found, padma, heliocentric, astrologer, predicted, devolving, observatory, named,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9596 0.0230 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0205 0.0246 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0344 0.0232 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0803 0.0225 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0709 0.0226 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0567 0.0225 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0161 0.0227 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9649 0.0209 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0012 0.0222 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9581 0.0225 sec/batch
# Nearest to all: inflorescence, macaroni, chosenness, dressage, dependency, petitioning, bocce, breaking,
# Nearest to five: two, zero, three, one, seven, four, six, eight,
# Nearest to time: unsure, subtracted, harmoniously, isps, unimpressed, monopoles, fairytale, driving,
# Nearest to between: mede, relative, luthier, baserunners, sapa, carpathians, erased, skirmishes,
# Nearest to many: oslo, unconsciously, modern, genetically, indirect, mpaja, while, badly,
# Nearest to new: riley, edison, dhtml, elitism, tacoma, york, hobbyist, by,
# Nearest to after: he, reconquest, pathogen, cabbie, through, aranese, shuttle, trollh,
# Nearest to system: usable, operating, purposes, cgt, brokered, internationalization, suse, tcl,
# Nearest to running: powerpc, kagan, hooked, carts, deeply, bunk, intend, tuck,
# Nearest to event: brezhnev, centimeter, clevelanders, trustworthy, memorial, phasing, saturdays, macrinus,
# Nearest to bible: biblical, judaism, jewish, testament, prophets, sourcebook, masoretic, hierarchy,
# Nearest to additional: drm, olympiads, direcci, yaobang, flavorings, originally, matzo, rung,
# Nearest to professional: goldfinger, amateur, gridiron, mahesh, handy, education, soccer, varsity,
# Nearest to mean: exactly, elevation, calculate, paderborn, cmmi, cofinal, arithmetic, specify,
# Nearest to pressure: wankel, turbines, solute, proportional, mech, resistance, valyria, hotol,
# Nearest to discovered: found, predicted, heliocentric, padma, observatory, devolving, astrologer, discovers,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9905 0.0228 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9309 0.0249 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0155 0.0228 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0467 0.0231 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0214 0.0225 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9928 0.0230 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9047 0.0228 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9790 0.0220 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9456 0.0217 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0027 0.0218 sec/batch
# Nearest to all: bocce, inflorescence, dressage, macaroni, hypochlorite, chosenness, couples, strictest,
# Nearest to five: two, zero, three, one, four, seven, six, eight,
# Nearest to time: unsure, subtracted, isps, harmoniously, monopoles, unimpressed, mastiff, cursory,
# Nearest to between: relative, mede, baserunners, pollen, caliente, erased, sapa, luthier,
# Nearest to many: unconsciously, oslo, mpaja, genetically, wellcome, badly, ephedrine, misinformation,
# Nearest to new: riley, edison, york, by, dhtml, elitism, the, characterisation,
# Nearest to after: pathogen, he, cabbie, reconquest, chargers, blastocyst, brendan, through,
# Nearest to system: usable, operating, brokered, purposes, inhalant, lfhild, internationalization, payload,
# Nearest to running: kagan, carts, hooked, powerpc, bunk, intend, tuck, losing,
# Nearest to event: brezhnev, centimeter, memorial, clevelanders, phasing, saturdays, trustworthy, macrinus,
# Nearest to bible: biblical, jewish, judaism, prophets, masoretic, testament, sourcebook, translations,
# Nearest to additional: drm, olympiads, direcci, yaobang, flavorings, originally, matzo, removal,
# Nearest to professional: goldfinger, amateur, gridiron, education, varsity, soccer, mahesh, vassar,
# Nearest to mean: exactly, elevation, paderborn, cofinal, calculate, cmmi, millimetres, arithmetic,
# Nearest to pressure: solute, wankel, turbines, proportional, mech, hotol, resistance, susceptibility,
# Nearest to discovered: found, predicted, heliocentric, observatory, astrologer, padma, named, devolving,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0029 0.0230 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0006 0.0231 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9779 0.0224 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0337 0.0207 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0227 0.0225 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9697 0.0230 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9999 0.0230 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9923 0.0236 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0022 0.0232 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9683 0.0229 sec/batch
# Nearest to all: chosenness, dressage, bocce, inflorescence, couples, macaroni, like, objectivist,
# Nearest to five: two, zero, three, one, seven, four, six, nine,
# Nearest to time: unsure, isps, subtracted, harmoniously, unimpressed, legato, monopoles, arpa,
# Nearest to between: mede, baserunners, relative, luthier, caliente, erased, pollen, artaxerxes,
# Nearest to many: oslo, unconsciously, genetically, victorian, mpaja, wellcome, teleplay, misinformation,
# Nearest to new: riley, edison, york, by, elitism, dhtml, hobbyist, characterisation,
# Nearest to after: he, pathogen, cabbie, reconquest, brendan, shuttle, blastocyst, publicly,
# Nearest to system: usable, operating, internationalization, brokered, payload, purposes, corporatism, tcl,
# Nearest to running: kagan, powerpc, bunk, carts, tuck, hooked, intend, deeply,
# Nearest to event: brezhnev, centimeter, memorial, trustworthy, clevelanders, phasing, chimpanzees, saturdays,
# Nearest to bible: biblical, judaism, jewish, prophets, masoretic, sourcebook, testament, ncb,
# Nearest to additional: drm, yaobang, direcci, olympiads, flavorings, originally, matzo, socketed,
# Nearest to professional: goldfinger, amateur, gridiron, mahesh, education, vassar, varsity, soccer,
# Nearest to mean: exactly, elevation, paderborn, cmmi, calculate, cofinal, millimetres, trumbull,
# Nearest to pressure: wankel, solute, turbines, proportional, mech, hotol, valyria, resistance,
# Nearest to discovered: found, heliocentric, observatory, predicted, named, devolving, padma, kepler,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0030 0.0193 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9874 0.0203 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9795 0.0231 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9852 0.0227 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0173 0.0216 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0198 0.0202 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9789 0.0227 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9777 0.0239 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9623 0.0239 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0143 0.0227 sec/batch
# Nearest to all: bocce, chosenness, inflorescence, palestine, vetted, can, dressage, like,
# Nearest to five: zero, two, three, one, seven, four, six, nine,
# Nearest to time: unsure, subtracted, isps, harmoniously, stood, unimpressed, monopoles, driving,
# Nearest to between: mede, baserunners, relative, erased, artaxerxes, caliente, luthier, assyrian,
# Nearest to many: oslo, unconsciously, genetically, mpaja, wellcome, ephedrine, badly, luxembourgish,
# Nearest to new: riley, york, edison, dhtml, by, elitism, hobbyist, bouvines,
# Nearest to after: reconquest, he, blockaded, pathogen, shuttle, was, aranese, kuril,
# Nearest to system: usable, operating, brokered, speculated, corporatism, lfhild, purposes, internationalization,
# Nearest to running: tuck, powerpc, kagan, hooked, deeply, carts, bunk, worldcon,
# ...
# Nearest to between: of, mede, and, both, with, absorbing, in, travel,
# Nearest to many: some, among, these, rulebooks, number, wellcome, in, there,
# Nearest to new: york, by, in, the, elitism, riley, of, edison,
# Nearest to after: had, a, he, was, before, pathogen, bankrupt, following,
# Nearest to system: operating, through, brokered, meninges, being, daylight, turnover, deriving,
# Nearest to running: hereby, tosses, drafted, tuck, kagan, powerpc, departmental, chesterfield,
# Nearest to event: centimeter, caused, brezhnev, trustworthy, seen, lunisolar, epoch, saturdays,
# Nearest to bible: biblical, judaism, masoretic, sourcebook, diatessaron, jewish, pentateuch, testament,
# Nearest to additional: originally, direcci, inclusion, flavorings, its, unix, olympiads, containing,
# Nearest to professional: amateur, gridiron, vassar, volunteer, skill, holst, training, recursive,
# Nearest to mean: calculate, variance, arithmetic, mahabad, resurgent, millimetres, exactly, elevation,
# Nearest to pressure: mech, minerals, wankel, solute, proportional, trowa, flows, expands,
# Nearest to discovered: found, discovery, mullet, lutterworth, reported, named, heliocentric, plinth,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8308 0.0242 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8744 0.0217 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8578 0.0181 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8744 0.0209 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8587 0.0206 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8866 0.0212 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8450 0.0210 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8209 0.0228 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8999 0.0224 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8595 0.0228 sec/batch
# Nearest to all: and, of, are, can, it, this, over, in,
# Nearest to five: three, zero, two, one, seven, six, four, eight,
# Nearest to time: at, isps, monopoles, cursory, timescale, harmoniously, to, reigned,
# Nearest to between: and, of, mede, with, both, from, dividing, absorbing,
# Nearest to many: some, among, there, rulebooks, these, number, wellcome, still,
# Nearest to new: york, by, elitism, edison, riley, hobbyist, of, emails,
# Nearest to after: had, before, was, he, a, pathogen, returned, bankrupt,
# Nearest to system: operating, through, brokered, being, meninges, daylight, macias, turnover,
# Nearest to running: hereby, tosses, tuck, breadth, drafted, bogies, kagan, powerpc,
# Nearest to event: trustworthy, centimeter, caused, seen, brezhnev, commutativity, lunisolar, epoch,
# Nearest to bible: biblical, judaism, sourcebook, masoretic, diatessaron, christians, pentateuch, arabization,
# Nearest to additional: direcci, originally, flavorings, its, unix, olympiads, inclusion, boasted,
# Nearest to professional: amateur, gridiron, vassar, volunteer, recursive, holst, skill, neutralise,
# Nearest to mean: calculate, variance, arithmetic, mahabad, millimetres, resurgent, exactly, elevation,
# Nearest to pressure: wankel, mech, proportional, minerals, solute, flows, trowa, expands,
# Nearest to discovered: found, discovery, lutterworth, reported, mullet, named, plinth, heliocentric,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.9015 0.0226 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8301 0.0225 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8334 0.0224 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8381 0.0223 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9108 0.0234 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8635 0.0224 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9672 0.0215 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8682 0.0239 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9211 0.0219 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8104 0.0214 sec/batch
# Nearest to all: and, are, can, of, it, this, over, four,
# Nearest to five: three, two, zero, six, seven, one, four, eight,
# Nearest to time: isps, driving, at, monopoles, cursory, reintroduced, voted, period,
# Nearest to between: mede, of, and, with, dividing, distinction, gamaliel, both,
# Nearest to many: some, among, there, these, number, still, wellcome, oslo,
# Nearest to new: york, by, elitism, riley, edison, benjamin, states, the,
# Nearest to after: had, was, he, before, a, returned, publicly, until,
# Nearest to system: operating, through, meninges, brokered, macias, daylight, turnover, being,
# Nearest to running: hereby, drafted, tosses, kagan, breadth, departmental, tuck, disintegrates,
# Nearest to event: trustworthy, centimeter, caused, seen, brezhnev, lunisolar, commutativity, osnabr,
# Nearest to bible: biblical, judaism, masoretic, sourcebook, jewish, diatessaron, christians, arabization,
# Nearest to additional: originally, direcci, flavorings, inclusion, olympiads, precedent, drm, gpcrs,
# Nearest to professional: amateur, gridiron, volunteer, vassar, recursive, holst, skill, ocogs,
# Nearest to mean: calculate, variance, resurgent, arithmetic, litha, mahabad, millimetres, fall,
# Nearest to pressure: wankel, mech, minerals, proportional, solute, expands, sardonic, flows,
# Nearest to discovered: found, discovery, mullet, lutterworth, reported, heliocentric, pasteur, named,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7998 0.0229 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8547 0.0231 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7717 0.0226 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8894 0.0226 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8652 0.0235 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8621 0.0236 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9110 0.0132 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8499 0.0225 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8331 0.0235 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8485 0.0202 sec/batch
# Nearest to all: and, of, can, are, it, this, in, perfect,
# Nearest to five: two, three, zero, one, four, seven, six, eight,
# Nearest to time: at, isps, driving, to, occurred, monopoles, reintroduced, was,
# Nearest to between: mede, and, of, in, both, with, gamaliel, absorbing,
# Nearest to many: some, among, rulebooks, number, these, still, are, there,
# Nearest to new: york, by, elitism, edison, riley, aaas, in, states,
# Nearest to after: had, was, before, a, he, pathogen, until, returned,
# Nearest to system: operating, being, through, brokered, meninges, macias, daylight, suburban,
# Nearest to running: hereby, powerpc, kagan, tosses, bogies, departmental, drafted, marginalize,
# Nearest to event: trustworthy, caused, centimeter, seen, brezhnev, commutativity, vehicular, lunisolar,
# Nearest to bible: biblical, judaism, christians, diatessaron, sourcebook, masoretic, jewish, pentateuch,
# Nearest to additional: originally, direcci, unix, boasted, flavorings, its, olympiads, gpcrs,
# Nearest to professional: amateur, volunteer, vassar, gridiron, skill, recursive, holst, training,
# Nearest to mean: calculate, variance, resurgent, litha, millimetres, mahabad, fall, arithmetic,
# Nearest to pressure: wankel, mech, minerals, proportional, solute, sardonic, trowa, expands,
# Nearest to discovered: found, discovery, mullet, reported, lutterworth, named, heliocentric, astrologer,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8052 0.0231 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8626 0.0231 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7931 0.0220 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8230 0.0236 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8319 0.0236 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8039 0.0220 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8769 0.0234 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7420 0.0218 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8302 0.0219 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7737 0.0208 sec/batch
# Nearest to all: of, and, are, it, can, the, this, for,
# Nearest to five: three, two, zero, four, six, seven, one, eight,
# Nearest to time: at, isps, to, monopoles, timescale, when, jitter, reintroduced,
# Nearest to between: of, and, with, in, mede, both, absorbing, important,
# Nearest to many: some, among, these, number, rulebooks, wellcome, known, there,
# Nearest to new: york, by, in, the, elitism, of, to, island,
# Nearest to after: had, was, a, he, before, publicly, returned, pathogen,
# Nearest to system: operating, through, being, brokered, meninges, macias, turnover, deriving,
# Nearest to running: hereby, bogies, drafted, tosses, departmental, chesterfield, powerpc, kagan,
# Nearest to event: caused, seen, trustworthy, centimeter, lunisolar, brezhnev, commutativity, future,
# Nearest to bible: biblical, judaism, diatessaron, sourcebook, christians, masoretic, testament, jewish,
# Nearest to additional: direcci, originally, its, flavorings, unix, inclusion, containing, olympiads,
# Nearest to professional: amateur, gridiron, volunteer, vassar, skill, recursive, education, ocogs,
# Nearest to mean: calculate, variance, millimetres, litha, fall, resurgent, trumbull, mahabad,
# Nearest to pressure: solute, minerals, proportional, mech, wankel, sardonic, flows, trowa,
# Nearest to discovered: found, discovery, mullet, lutterworth, reported, named, astrologer, plinth,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7957 0.0207 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8236 0.0220 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8534 0.0226 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8203 0.0221 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8243 0.0196 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9050 0.0203 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8308 0.0228 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8564 0.0229 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8383 0.0225 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8259 0.0229 sec/batch
# Nearest to all: and, of, are, it, this, can, in, the,
# Nearest to five: three, two, zero, four, six, seven, one, eight,
# Nearest to time: at, isps, reintroduced, monopoles, jitter, to, driving, occurred,
# Nearest to between: of, with, mede, in, absorbing, and, another, as,
# Nearest to many: some, among, known, number, rulebooks, these, there, wellcome,
# Nearest to new: york, by, in, of, the, edison, elitism, riley,
# Nearest to after: had, was, he, before, a, returned, pathogen, shortly,
# Nearest to system: operating, through, being, brokered, macias, meninges, turnover, bef,
# Nearest to running: hereby, bogies, drafted, chesterfield, tosses, kagan, breadth, departmental,
# Nearest to event: caused, centimeter, trustworthy, seen, brezhnev, commutativity, events, epoch,
# Nearest to bible: biblical, judaism, diatessaron, sourcebook, christians, masoretic, jewish, arabization,
# Nearest to additional: direcci, originally, flavorings, its, unix, baxter, inclusion, boasted,
# Nearest to professional: amateur, gridiron, volunteer, vassar, skill, recursive, holst, training,
# Nearest to mean: calculate, variance, trumbull, mahabad, resurgent, millimetres, franken, fall,
# Nearest to pressure: proportional, wankel, mech, solute, minerals, trowa, gbase, flows,
# Nearest to discovered: found, discovery, mullet, reported, lutterworth, named, astrologer, predicted,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8400 0.0211 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8512 0.0216 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8366 0.0240 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8249 0.0210 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8520 0.0227 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8553 0.0239 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8407 0.0215 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8408 0.0195 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8036 0.0237 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8154 0.0222 sec/batch
# Nearest to all: and, of, are, this, can, it, the, in,
# Nearest to five: three, two, zero, four, seven, one, six, eight,
# Nearest to time: at, driving, reintroduced, monopoles, isps, period, when, stood,
# Nearest to between: of, with, mede, and, distinction, travel, as, in,
# Nearest to many: some, number, these, among, are, known, still, there,
# Nearest to new: york, by, in, edison, the, benjamin, riley, elitism,
# Nearest to after: had, was, before, he, a, shortly, until, pathogen,
# Nearest to system: operating, through, being, a, brokered, macias, opposed, systems,
# Nearest to running: hereby, bogies, departmental, drafted, tosses, breadth, marginalize, powerpc,
# Nearest to event: caused, trustworthy, centimeter, seen, events, periods, lunisolar, commutativity,
# Nearest to bible: biblical, judaism, christians, diatessaron, masoretic, sourcebook, arabization, jewish,
# Nearest to additional: direcci, originally, flavorings, its, unix, precedent, gpcrs, baxter,
# Nearest to professional: amateur, volunteer, gridiron, vassar, skill, recursive, training, ocogs,
# Nearest to mean: calculate, variance, millimetres, fall, mahabad, trumbull, litha, paderborn,
# Nearest to pressure: proportional, wankel, mech, minerals, solute, medalists, trowa, flows,
# Nearest to discovered: found, discovery, mullet, reported, lutterworth, pasteur, heliocentric, predicted,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8373 0.0207 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8174 0.0226 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9252 0.0230 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9246 0.0209 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8828 0.0180 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8319 0.0186 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7953 0.0185 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8628 0.0222 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7571 0.0218 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8384 0.0194 sec/batch
# Nearest to all: and, of, can, this, are, it, the, in,
# Nearest to five: three, two, zero, one, seven, four, six, eight,
# Nearest to time: at, driving, reintroduced, when, isps, monopoles, advent, unanimity,
# Nearest to between: of, with, mede, in, travel, both, important, as,
# Nearest to many: some, among, there, number, known, in, these, are,
# Nearest to new: york, by, in, elitism, edison, aaas, resisting, emails,
# Nearest to after: had, before, was, he, a, shortly, soon, until,
# Nearest to system: operating, being, through, a, systems, brokered, suse, launceston,
# Nearest to running: hereby, bogies, departmental, marginalize, drafted, kagan, chesterfield, powerpc,
# Nearest to event: caused, trustworthy, centimeter, seen, events, commutativity, periods, lunisolar,
# Nearest to bible: biblical, judaism, diatessaron, intermarriages, christians, pentateuch, stonemasons, masoretic,
# Nearest to additional: direcci, containing, originally, gpcrs, flavorings, precedent, unix, inclusion,
# Nearest to professional: amateur, volunteer, vassar, gridiron, recursive, skill, training, ocogs,
# Nearest to mean: calculate, variance, arithmetic, millimetres, mahabad, fall, resurgent, litha,
# Nearest to pressure: proportional, mech, wankel, minerals, solute, flows, sardonic, detailing,
# Nearest to discovered: found, mullet, discovery, reported, lutterworth, pasteur, psychiatrists, elliptic,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8814 0.0198 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8232 0.0234 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
